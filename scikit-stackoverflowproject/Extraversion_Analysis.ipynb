# %%
import pandas as pd
import matplotlib.pyplot as plt
import hashlib
import random
 
# hasher = hashlib.md5()
# with open('test.csv', 'rb') as afile:
#     buf = afile.read()
#     hasher.update(buf)
#     print(buf)
# print(hasher.hexdigest())

df = pd.read_csv('survey_results_public.csv')
new_df = df
df = df[df.SocialMedia != "Hello"]
to_drop = ["Respondent", "Country", "MainBranch", "OpenSource", "Employment", "Student", "EdLevel", "UndergradMajor", \
           "EduOther","OrgSize","DevType","YearsCode","Age1stCode","YearsCodePro","CareerSat","JobSat","MgrIdiot",\
           "MgrMoney","MgrWant","JobSeek","LastHireDate","LastInt","FizzBuzz","JobFactors","CurrencySymbol",\
           "CurrencyDesc","CompTotal","CompFreq","ConvertedComp", "WorkWeekHrs","WorkPlan","WorkChallenge",\
           "WorkRemote","WorkLoc","ImpSyn","CodeRev","CodeRevHrs","UnitTests","PurchaseHow","PurchaseWhat",\
          "LanguageWorkedWith","LanguageDesireNextYear","DatabaseWorkedWith","DatabaseDesireNextYear",\
          "PlatformWorkedWith","PlatformDesireNextYear","WebFrameWorkedWith","WebFrameDesireNextYear",\
          "MiscTechWorkedWith","MiscTechDesireNextYear","DevEnviron","OpSys", "Containers","BlockchainOrg",\
          "BlockchainIs","OffOn","ScreenName","SOVisit1st","SOTimeSaved","SOHowMuchTime","WelcomeChange",\
          "Age","Dependents","Ethnicity", "SurveyLength", "SurveyEase"]
df = df.drop(to_drop,axis=1)
df = df.dropna()
print(len(df))
display(df)
print(df.columns)
random.seed()
# Out:
# 42938
#       Hobbyist                                        OpenSourcer  \
# 1           No                            Less than once per year
# 2          Yes                                              Never
# 3           No                                              Never
# 4          Yes                         Once a month or more often
# 5          Yes                                              Never
# ...        ...                                                ...
# 88318      Yes                            Less than once per year
# 88320      Yes  Less than once a month but more than once per ...
# 88324      Yes                            Less than once per year
# 88325      Yes                            Less than once per year
# 88330      Yes                         Once a month or more often
#
#                                             ResumeUpdate BetterLife  ITperson  \
# 1      Something else changed (education, award, medi...        Yes       Yes
# 2                       I was preparing for a job search        Yes       Yes
# 3                       I was preparing for a job search        Yes      SIGH
# 4                       I was preparing for a job search        Yes  Also Yes
# 5      I heard about a job opportunity (from a recrui...         No       Yes
# ...                                                  ...        ...       ...
# 88318   My job status changed (promotion, new job, etc.)        Yes      SIGH
# 88320                   I was preparing for a job search         No  Also Yes
# 88324  I heard about a job opportunity (from a recrui...        Yes       Yes
# 88325                   I was preparing for a job search        Yes       Yes
# 88330   My job status changed (promotion, new job, etc.)        Yes      SIGH
#
#       SocialMedia              Extraversion                      SOVisitFreq  \
# 1       Instagram                    Online            Daily or almost daily
# 2          Reddit  In real life (in person)             A few times per week
# 3          Reddit  In real life (in person)            Daily or almost daily
# 4        Facebook  In real life (in person)           Multiple times per day
# 5         YouTube  In real life (in person)  A few times per month or weekly
# ...           ...                       ...                              ...
# 88318      Reddit  In real life (in person)            Daily or almost daily
# 88320     YouTube  In real life (in person)           Multiple times per day
# 88324    Facebook                    Online  A few times per month or weekly
# 88325     Twitter                    Online           Multiple times per day
# 88330      Reddit  In real life (in person)             A few times per week
#
#                                                SOVisitTo  \
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# 5                     Find answers to specific questions
# ...                                                  ...
# 88318  Find answers to specific questions;Learn how t...
# 88320  Find answers to specific questions;Learn how t...
# 88324                 Find answers to specific questions
# 88325  Find answers to specific questions;Learn how t...
# 88330  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer SOAccount  \
# 1               3-5 times per week       Yes
# 2              6-10 times per week       Yes
# 3               1-2 times per week       Yes
# 4      More than 10 times per week       Yes
# 5          Less than once per week       Yes
# ...                            ...       ...
# 88318          6-10 times per week       Yes
# 88320          6-10 times per week       Yes
# 88324      Less than once per week       Yes
# 88325           3-5 times per week       Yes
# 88330           1-2 times per week       Yes
#
#                                               SOPartFreq  \
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# 5      I have never participated in Q&A on Stack Over...
# ...                                                  ...
# 88318  I have never participated in Q&A on Stack Over...
# 88320                               A few times per week
# 88324  I have never participated in Q&A on Stack Over...
# 88325                               A few times per week
# 88330                    A few times per month or weekly
#
#                                                   SOJobs  \
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# 5      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88318  No, I knew that Stack Overflow had a job board...
# 88320                                                Yes
# 88324  No, I knew that Stack Overflow had a job board...
# 88325                                                Yes
# 88330  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams           SOComm  \
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# 5                    No, and I don't know what those are   No, not really
# ...                                                  ...              ...
# 88318  No, I've heard of them, but I am not part of a...   No, not at all
# 88320  No, I've heard of them, but I am not part of a...  Yes, definitely
# 88324                No, and I don't know what those are    Yes, somewhat
# 88325  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 88330  No, I've heard of them, but I am not part of a...   No, not really
#
#                                             SONewContent Gender Trans  \
# 1      Tech articles written by other developers;Indu...    Man    No
# 2      Tech meetups or events in your area;Courses on...    Man    No
# 3      Tech articles written by other developers;Indu...    Man    No
# 4      Tech meetups or events in your area;Courses on...    Man    No
# 5      Tech articles written by other developers;Indu...    Man    No
# ...                                                  ...    ...   ...
# 88318  Tech articles written by other developers;Cour...    Man    No
# 88320  Tech articles written by other developers;Indu...    Man    No
# 88324  Tech articles written by other developers;Cour...    Man    No
# 88325  Tech articles written by other developers;Indu...    Man    No
# 88330          Tech articles written by other developers    Man    No
#
#                      Sexuality
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# 5      Straight / Heterosexual
# ...                        ...
# 88318  Straight / Heterosexual
# 88320           Gay or Lesbian
# 88324  Straight / Heterosexual
# 88325  Straight / Heterosexual
# 88330  Straight / Heterosexual
#
# [42938 rows x 19 columns]
# Index(['Hobbyist', 'OpenSourcer', 'ResumeUpdate', 'BetterLife', 'ITperson',
#        'SocialMedia', 'Extraversion', 'SOVisitFreq', 'SOVisitTo',
#        'SOFindAnswer', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'SONewContent', 'Gender', 'Trans', 'Sexuality'],
#       dtype='object')

# %%
def text_to_scores(temp_df, column_name, bins, scores):
    for i in range(len(bins)):
        temp_df.loc[:, column_name] = temp_df.loc[:, column_name].replace(bins[i], scores[i])
    return temp_df

# %%
def split_categorical(temp_df, column_name):
    unique_values = temp_df.loc[:, column_name].unique()
    column_index = temp_df.columns.get_indexer_for([column_name])[0]
    print(unique_values)
    for category in unique_values:
        temp_df[category] = temp_df[column_name]
        for i in range(len(temp_df[category])):
            if temp_df.iloc[i, column_index] != category:
                temp_df.iloc[i, column_index] = False
            else:
                temp_df.iloc[i, column_index] = True
    return temp_df

# %%
df = split_categorical(df, "ResumeUpdate")
# Out:
# ['Something else changed (education, award, media, etc.)'
#  'I was preparing for a job search'
#  'I heard about a job opportunity (from a recruiter, online job posting, etc.)'
#  'My job status changed (promotion, new job, etc.)'
#  'I had a negative experience or interaction at work'
#  'Re-entry into the workforce']

# %%
for i in range(len(df)):
    column_index = df.columns.get_indexer_for(['Something else changed (education, award, media, etc.)'])[0]
    value = df.iloc[i, column_index]
    if value == 'Something else changed (education, award, media, etc.)':
        df.iloc[i, column_index] = True
    else:
        df.iloc[i, column_index] = False

print(display(df.head()))
# Out:
#   Hobbyist                 OpenSourcer ResumeUpdate BetterLife  ITperson  \
# 1       No     Less than once per year        False        Yes       Yes
# 2      Yes                       Never        False        Yes       Yes
# 3       No                       Never        False        Yes      SIGH
# 4      Yes  Once a month or more often        False        Yes  Also Yes
# 5      Yes                       Never        False         No       Yes
#
#   SocialMedia              Extraversion                      SOVisitFreq  \
# 1   Instagram                    Online            Daily or almost daily
# 2      Reddit  In real life (in person)             A few times per week
# 3      Reddit  In real life (in person)            Daily or almost daily
# 4    Facebook  In real life (in person)           Multiple times per day
# 5     YouTube  In real life (in person)  A few times per month or weekly
#
#                                            SOVisitTo  \
# 1  Find answers to specific questions;Learn how t...
# 2  Find answers to specific questions;Learn how t...
# 3  Find answers to specific questions;Pass the ti...
# 4                 Find answers to specific questions
# 5                 Find answers to specific questions
#
#                   SOFindAnswer  ...  \
# 1           3-5 times per week  ...
# 2          6-10 times per week  ...
# 3           1-2 times per week  ...
# 4  More than 10 times per week  ...
# 5      Less than once per week  ...
#
#                                         SONewContent Gender Trans  \
# 1  Tech articles written by other developers;Indu...    Man    No
# 2  Tech meetups or events in your area;Courses on...    Man    No
# 3  Tech articles written by other developers;Indu...    Man    No
# 4  Tech meetups or events in your area;Courses on...    Man    No
# 5  Tech articles written by other developers;Indu...    Man    No
#
#                  Sexuality  \
# 1  Straight / Heterosexual
# 2  Straight / Heterosexual
# 3  Straight / Heterosexual
# 4  Straight / Heterosexual
# 5  Straight / Heterosexual
#
#   Something else changed (education, award, media, etc.)  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#   I was preparing for a job search  \
# 1                             True
# 2                            False
# 3                            False
# 4                            False
# 5                            False
#
#   I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#   My job status changed (promotion, new job, etc.)  \
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# 5                                            False
#
#   I had a negative experience or interaction at work  \
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# 5                                              False
#
#   Re-entry into the workforce
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# 5                       False
#
# [5 rows x 25 columns]
# None

# %%
soComm_bins = ['No, not at all', 'No, not really', "Neutral", "Not sure", "Yes, somewhat", "Yes, definitely"]
soComm_scores = [-1, -0.5, 0, 0, 0.5, 1]

soFreq_bins =["I have never participated in Q&A on Stack Overflow","Less than once per month or monthly","A few times per month or weekly","A few times per week","Daily or almost daily","Multiple times per day"]
soFreq_scores = [-1, -0.5, 0, 0.5, 1, 1]

soAccount_bins = ['No', "Not sure / can\'t remember'", "Yes"]
soAccount_scores = [-1, 0, 1]

satisfaction_bins = ['Very dissastisfied', "Slightly dissatisfied", 'Neither satisfied nor dissatisfied', 'Slightly satisfied', 'Very satisfied']
satisfaction_scores = [-1, -0.5, 0, 0.5, 1]

binary_bins = ["Yes", "No"]
binary_scores = [1, -1]

string_boolean_bins = ['True', 'False']
string_boolean_scores = [1, -1]

boolean_bins = [True, False]
boolean_scores = [1, -1]

opensourcer_bins = ["Never", "Less than once per year", "Less than once a month but more than once per year", "Once a month or more often"]
opensourcer_scores = [-1, -0.5, 0.5, 1]

findAnswer_bins = ["NA", "Less than once per week", "1-2 times per week", "3-5 times per week", "6-10 times per week", "More than 10 times per week"]
findAnswer_scores = [-1, -0.5, 0, 0.5, 1, 1]

soJobs_bins = ["No, I didn't know that Stack Overflow had a job board", "No, I knew that Stack Overflow had a job board but have never used or visited it", "Yes"]
soJobs_scores = [-1, -1, 1]

soTeams_bins = ["No, and I don't know what those are", "No, I've heard of them, but I am not part of a private Q&A instance", "Yes"]
soTeams_scores = [-1, -1, 1]

# %%
df = text_to_scores(df, 'SOComm', soComm_bins, soComm_scores)
df = text_to_scores(df, 'SOAccount', soAccount_bins, soAccount_scores)
df = text_to_scores(df, 'SOPartFreq', soFreq_bins, soFreq_scores)
df = text_to_scores(df, 'SOVisitFreq', soFreq_bins, soFreq_scores)
df = text_to_scores(df, 'I was preparing for a job search', boolean_bins, boolean_scores)
df = text_to_scores(df, 'Something else changed (education, award, media, etc.)', boolean_bins, boolean_scores)
df = text_to_scores(df, 'I heard about a job opportunity (from a recruiter, online job posting, etc.)', boolean_bins, boolean_scores)
df = text_to_scores(df, 'My job status changed (promotion, new job, etc.)', boolean_bins, boolean_scores)
df = text_to_scores(df, 'I had a negative experience or interaction at work', boolean_bins, boolean_scores)
df = text_to_scores(df, 'Re-entry into the workforce', boolean_bins, boolean_scores)
df = text_to_scores(df, 'OpenSourcer', opensourcer_bins, opensourcer_scores)
df = text_to_scores(df, 'SOFindAnswer', findAnswer_bins, findAnswer_scores)
df = text_to_scores(df, 'SOJobs', soJobs_bins, soJobs_scores)
df = text_to_scores(df, 'EntTeams', soTeams_bins, soTeams_scores)
df = text_to_scores(df, 'Hobbyist', binary_bins, binary_scores)

# %%
display(df)
# Out:
#        Hobbyist  OpenSourcer ResumeUpdate BetterLife  ITperson SocialMedia  \
# 1            -1         -0.5        False        Yes       Yes   Instagram
# 2             1         -1.0        False        Yes       Yes      Reddit
# 3            -1         -1.0        False        Yes      SIGH      Reddit
# 4             1          1.0        False        Yes  Also Yes    Facebook
# 5             1         -1.0        False         No       Yes     YouTube
# ...         ...          ...          ...        ...       ...         ...
# 88318         1         -0.5        False        Yes      SIGH      Reddit
# 88320         1          0.5        False         No  Also Yes     YouTube
# 88324         1         -0.5        False        Yes       Yes    Facebook
# 88325         1         -0.5        False        Yes       Yes     Twitter
# 88330         1          1.0        False        Yes      SIGH      Reddit
#
#                    Extraversion  SOVisitFreq  \
# 1                        Online          1.0
# 2      In real life (in person)          0.5
# 3      In real life (in person)          1.0
# 4      In real life (in person)          1.0
# 5      In real life (in person)          0.0
# ...                         ...          ...
# 88318  In real life (in person)          1.0
# 88320  In real life (in person)          1.0
# 88324                    Online          0.0
# 88325                    Online          1.0
# 88330  In real life (in person)          0.5
#
#                                                SOVisitTo  SOFindAnswer  ...  \
# 1      Find answers to specific questions;Learn how t...           0.5  ...
# 2      Find answers to specific questions;Learn how t...           1.0  ...
# 3      Find answers to specific questions;Pass the ti...           0.0  ...
# 4                     Find answers to specific questions           1.0  ...
# 5                     Find answers to specific questions          -0.5  ...
# ...                                                  ...           ...  ...
# 88318  Find answers to specific questions;Learn how t...           1.0  ...
# 88320  Find answers to specific questions;Learn how t...           1.0  ...
# 88324                 Find answers to specific questions          -0.5  ...
# 88325  Find answers to specific questions;Learn how t...           0.5  ...
# 88330  Find answers to specific questions;Learn how t...           0.0  ...
#
#                                             SONewContent  Gender  Trans  \
# 1      Tech articles written by other developers;Indu...     Man     No
# 2      Tech meetups or events in your area;Courses on...     Man     No
# 3      Tech articles written by other developers;Indu...     Man     No
# 4      Tech meetups or events in your area;Courses on...     Man     No
# 5      Tech articles written by other developers;Indu...     Man     No
# ...                                                  ...     ...    ...
# 88318  Tech articles written by other developers;Cour...     Man     No
# 88320  Tech articles written by other developers;Indu...     Man     No
# 88324  Tech articles written by other developers;Cour...     Man     No
# 88325  Tech articles written by other developers;Indu...     Man     No
# 88330          Tech articles written by other developers     Man     No
#
#                      Sexuality  \
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# 5      Straight / Heterosexual
# ...                        ...
# 88318  Straight / Heterosexual
# 88320           Gay or Lesbian
# 88324  Straight / Heterosexual
# 88325  Straight / Heterosexual
# 88330  Straight / Heterosexual
#
#        Something else changed (education, award, media, etc.)  \
# 1                                                      1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#       I was preparing for a job search  \
# 1                                    1
# 2                                   -1
# 3                                   -1
# 4                                   -1
# 5                                   -1
# ...                                ...
# 88318                               -1
# 88320                               -1
# 88324                               -1
# 88325                               -1
# 88330                               -1
#
#       I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#       My job status changed (promotion, new job, etc.)  \
# 1                                                   -1
# 2                                                   -1
# 3                                                   -1
# 4                                                   -1
# 5                                                   -1
# ...                                                ...
# 88318                                               -1
# 88320                                               -1
# 88324                                               -1
# 88325                                               -1
# 88330                                               -1
#
#       I had a negative experience or interaction at work  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#        Re-entry into the workforce
# 1                               -1
# 2                               -1
# 3                               -1
# 4                               -1
# 5                               -1
# ...                            ...
# 88318                           -1
# 88320                           -1
# 88324                           -1
# 88325                           -1
# 88330                           -1
#
# [42938 rows x 25 columns]

# %%
old_df = df

# %%
df = old_df
# df = split_categorical(df, "Extraversion")
df['ExtraversionCol'] = df.loc[:, 'Extraversion']
# to_drop = []
# indexNamesArr = df.index.values
# irl_index = df.columns.get_indexer_for(['ExtraversionCol'])[0]
# for i in range(len(df)):
#     column_val = df.iloc[i, irl_index]
#     if column_val == "Online" or column_val == "In real life (in person)":
#         df.iloc[i, irl_index] = True
#     elif column_val == "Neither":
#         df.iloc[i, irl_index] = False
#     else:
#         to_drop.append(indexNamesArr[i])
# df.drop(labels=to_drop, axis=0)
extraversion_master_bins = ["Online", "In real life (in person)", "Neither"]
extraversion_master_scores = [True, True, False]
df = text_to_scores(df, 'ExtraversionCol', extraversion_master_bins, extraversion_master_scores)
print(len(df))
# Out:
# 42938

# %%
# indexNamesArr = df.index.values
# irl_index = df.columns.get_indexer_for(['ExtraversionCol'])[0]
# for i in range(len(df)):
display(df)
# Out:
#        Hobbyist  OpenSourcer ResumeUpdate BetterLife  ITperson SocialMedia  \
# 1            -1         -0.5        False        Yes       Yes   Instagram
# 2             1         -1.0        False        Yes       Yes      Reddit
# 3            -1         -1.0        False        Yes      SIGH      Reddit
# 4             1          1.0        False        Yes  Also Yes    Facebook
# 5             1         -1.0        False         No       Yes     YouTube
# ...         ...          ...          ...        ...       ...         ...
# 88318         1         -0.5        False        Yes      SIGH      Reddit
# 88320         1          0.5        False         No  Also Yes     YouTube
# 88324         1         -0.5        False        Yes       Yes    Facebook
# 88325         1         -0.5        False        Yes       Yes     Twitter
# 88330         1          1.0        False        Yes      SIGH      Reddit
#
#                    Extraversion  SOVisitFreq  \
# 1                        Online          1.0
# 2      In real life (in person)          0.5
# 3      In real life (in person)          1.0
# 4      In real life (in person)          1.0
# 5      In real life (in person)          0.0
# ...                         ...          ...
# 88318  In real life (in person)          1.0
# 88320  In real life (in person)          1.0
# 88324                    Online          0.0
# 88325                    Online          1.0
# 88330  In real life (in person)          0.5
#
#                                                SOVisitTo  SOFindAnswer  ...  \
# 1      Find answers to specific questions;Learn how t...           0.5  ...
# 2      Find answers to specific questions;Learn how t...           1.0  ...
# 3      Find answers to specific questions;Pass the ti...           0.0  ...
# 4                     Find answers to specific questions           1.0  ...
# 5                     Find answers to specific questions          -0.5  ...
# ...                                                  ...           ...  ...
# 88318  Find answers to specific questions;Learn how t...           1.0  ...
# 88320  Find answers to specific questions;Learn how t...           1.0  ...
# 88324                 Find answers to specific questions          -0.5  ...
# 88325  Find answers to specific questions;Learn how t...           0.5  ...
# 88330  Find answers to specific questions;Learn how t...           0.0  ...
#
#        Gender  Trans                Sexuality  \
# 1         Man     No  Straight / Heterosexual
# 2         Man     No  Straight / Heterosexual
# 3         Man     No  Straight / Heterosexual
# 4         Man     No  Straight / Heterosexual
# 5         Man     No  Straight / Heterosexual
# ...       ...    ...                      ...
# 88318     Man     No  Straight / Heterosexual
# 88320     Man     No           Gay or Lesbian
# 88324     Man     No  Straight / Heterosexual
# 88325     Man     No  Straight / Heterosexual
# 88330     Man     No  Straight / Heterosexual
#
#        Something else changed (education, award, media, etc.)  \
# 1                                                      1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#        I was preparing for a job search  \
# 1                                     1
# 2                                    -1
# 3                                    -1
# 4                                    -1
# 5                                    -1
# ...                                 ...
# 88318                                -1
# 88320                                -1
# 88324                                -1
# 88325                                -1
# 88330                                -1
#
#       I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#       My job status changed (promotion, new job, etc.)  \
# 1                                                   -1
# 2                                                   -1
# 3                                                   -1
# 4                                                   -1
# 5                                                   -1
# ...                                                ...
# 88318                                               -1
# 88320                                               -1
# 88324                                               -1
# 88325                                               -1
# 88330                                               -1
#
#       I had a negative experience or interaction at work  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#       Re-entry into the workforce  ExtraversionCol
# 1                              -1             True
# 2                              -1             True
# 3                              -1             True
# 4                              -1             True
# 5                              -1             True
# ...                           ...              ...
# 88318                          -1             True
# 88320                          -1             True
# 88324                          -1             True
# 88325                          -1             True
# 88330                          -1             True
#
# [42938 rows x 26 columns]

# %%
# df = split_categorical(df, "Extraversion")
df['Online'] = df.loc[:, 'Extraversion']
to_drop = []
indexNamesArr = df.index.values
irl_index = df.columns.get_indexer_for(['Online'])[0]
for i in range(len(df)):
    column_val = df.iloc[i, irl_index]
    if column_val == "Online":
        df.iloc[i, irl_index] = True
    elif column_val == "Neither":
        df.iloc[i, irl_index] = False
    elif column_val == "In real life (in person)":
        df.iloc[i, irl_index] = float('nan')
#     else:
#         to_drop.append(indexNamesArr[i])
# df.drop(labels=to_drop, axis=0)
print(len(df))
# Out:
# 42938

# %%
# df = split_categorical(df, "Extraversion")
df['IRL'] = df.loc[:, 'Extraversion']
to_drop = []
indexNamesArr = df.index.values
irl_index = df.columns.get_indexer_for(['IRL'])[0]
for i in range(len(df)):
    column_val = df.iloc[i, irl_index]
    if column_val == "In real life (in person)":
        df.iloc[i, irl_index] = True
    elif column_val == "Neither":
        df.iloc[i, irl_index] = False
    elif column_val == "Online":
        df.iloc[i, irl_index] = float('nan')
#     else:
#         to_drop.append(indexNamesArr[i])
# df.drop(labels=to_drop, axis=0)
print(len(df))
# Out:
# 42938

# %%
display(df)
# Out:
#        Hobbyist  OpenSourcer ResumeUpdate BetterLife  ITperson SocialMedia  \
# 1            -1         -0.5        False        Yes       Yes   Instagram
# 2             1         -1.0        False        Yes       Yes      Reddit
# 3            -1         -1.0        False        Yes      SIGH      Reddit
# 4             1          1.0        False        Yes  Also Yes    Facebook
# 5             1         -1.0        False         No       Yes     YouTube
# ...         ...          ...          ...        ...       ...         ...
# 88318         1         -0.5        False        Yes      SIGH      Reddit
# 88320         1          0.5        False         No  Also Yes     YouTube
# 88324         1         -0.5        False        Yes       Yes    Facebook
# 88325         1         -0.5        False        Yes       Yes     Twitter
# 88330         1          1.0        False        Yes      SIGH      Reddit
#
#                    Extraversion  SOVisitFreq  \
# 1                        Online          1.0
# 2      In real life (in person)          0.5
# 3      In real life (in person)          1.0
# 4      In real life (in person)          1.0
# 5      In real life (in person)          0.0
# ...                         ...          ...
# 88318  In real life (in person)          1.0
# 88320  In real life (in person)          1.0
# 88324                    Online          0.0
# 88325                    Online          1.0
# 88330  In real life (in person)          0.5
#
#                                                SOVisitTo  SOFindAnswer  ...  \
# 1      Find answers to specific questions;Learn how t...           0.5  ...
# 2      Find answers to specific questions;Learn how t...           1.0  ...
# 3      Find answers to specific questions;Pass the ti...           0.0  ...
# 4                     Find answers to specific questions           1.0  ...
# 5                     Find answers to specific questions          -0.5  ...
# ...                                                  ...           ...  ...
# 88318  Find answers to specific questions;Learn how t...           1.0  ...
# 88320  Find answers to specific questions;Learn how t...           1.0  ...
# 88324                 Find answers to specific questions          -0.5  ...
# 88325  Find answers to specific questions;Learn how t...           0.5  ...
# 88330  Find answers to specific questions;Learn how t...           0.0  ...
#
#                      Sexuality  \
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# 5      Straight / Heterosexual
# ...                        ...
# 88318  Straight / Heterosexual
# 88320           Gay or Lesbian
# 88324  Straight / Heterosexual
# 88325  Straight / Heterosexual
# 88330  Straight / Heterosexual
#
#        Something else changed (education, award, media, etc.)  \
# 1                                                      1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#        I was preparing for a job search  \
# 1                                     1
# 2                                    -1
# 3                                    -1
# 4                                    -1
# 5                                    -1
# ...                                 ...
# 88318                                -1
# 88320                                -1
# 88324                                -1
# 88325                                -1
# 88330                                -1
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#        My job status changed (promotion, new job, etc.)  \
# 1                                                    -1
# 2                                                    -1
# 3                                                    -1
# 4                                                    -1
# 5                                                    -1
# ...                                                 ...
# 88318                                                -1
# 88320                                                -1
# 88324                                                -1
# 88325                                                -1
# 88330                                                -1
#
#       I had a negative experience or interaction at work  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#       Re-entry into the workforce ExtraversionCol Online   IRL
# 1                              -1            True   True   NaN
# 2                              -1            True    NaN  True
# 3                              -1            True    NaN  True
# 4                              -1            True    NaN  True
# 5                              -1            True    NaN  True
# ...                           ...             ...    ...   ...
# 88318                          -1            True    NaN  True
# 88320                          -1            True    NaN  True
# 88324                          -1            True   True   NaN
# 88325                          -1            True   True   NaN
# 88330                          -1            True    NaN  True
#
# [42938 rows x 28 columns]

# %%
df = text_to_scores(df, 'ExtraversionCol', boolean_bins, boolean_scores)
df = text_to_scores(df, 'Online', boolean_bins, boolean_scores)
df = text_to_scores(df, 'IRL', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'In real life (in person)', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'Online', boolean_bins, boolean_scores)

display(df)
# Out:
#        Hobbyist  OpenSourcer ResumeUpdate BetterLife  ITperson SocialMedia  \
# 1            -1         -0.5        False        Yes       Yes   Instagram
# 2             1         -1.0        False        Yes       Yes      Reddit
# 3            -1         -1.0        False        Yes      SIGH      Reddit
# 4             1          1.0        False        Yes  Also Yes    Facebook
# 5             1         -1.0        False         No       Yes     YouTube
# ...         ...          ...          ...        ...       ...         ...
# 88318         1         -0.5        False        Yes      SIGH      Reddit
# 88320         1          0.5        False         No  Also Yes     YouTube
# 88324         1         -0.5        False        Yes       Yes    Facebook
# 88325         1         -0.5        False        Yes       Yes     Twitter
# 88330         1          1.0        False        Yes      SIGH      Reddit
#
#                    Extraversion  SOVisitFreq  \
# 1                        Online          1.0
# 2      In real life (in person)          0.5
# 3      In real life (in person)          1.0
# 4      In real life (in person)          1.0
# 5      In real life (in person)          0.0
# ...                         ...          ...
# 88318  In real life (in person)          1.0
# 88320  In real life (in person)          1.0
# 88324                    Online          0.0
# 88325                    Online          1.0
# 88330  In real life (in person)          0.5
#
#                                                SOVisitTo  SOFindAnswer  ...  \
# 1      Find answers to specific questions;Learn how t...           0.5  ...
# 2      Find answers to specific questions;Learn how t...           1.0  ...
# 3      Find answers to specific questions;Pass the ti...           0.0  ...
# 4                     Find answers to specific questions           1.0  ...
# 5                     Find answers to specific questions          -0.5  ...
# ...                                                  ...           ...  ...
# 88318  Find answers to specific questions;Learn how t...           1.0  ...
# 88320  Find answers to specific questions;Learn how t...           1.0  ...
# 88324                 Find answers to specific questions          -0.5  ...
# 88325  Find answers to specific questions;Learn how t...           0.5  ...
# 88330  Find answers to specific questions;Learn how t...           0.0  ...
#
#                      Sexuality  \
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# 5      Straight / Heterosexual
# ...                        ...
# 88318  Straight / Heterosexual
# 88320           Gay or Lesbian
# 88324  Straight / Heterosexual
# 88325  Straight / Heterosexual
# 88330  Straight / Heterosexual
#
#        Something else changed (education, award, media, etc.)  \
# 1                                                      1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#        I was preparing for a job search  \
# 1                                     1
# 2                                    -1
# 3                                    -1
# 4                                    -1
# 5                                    -1
# ...                                 ...
# 88318                                -1
# 88320                                -1
# 88324                                -1
# 88325                                -1
# 88330                                -1
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#        My job status changed (promotion, new job, etc.)  \
# 1                                                    -1
# 2                                                    -1
# 3                                                    -1
# 4                                                    -1
# 5                                                    -1
# ...                                                 ...
# 88318                                                -1
# 88320                                                -1
# 88324                                                -1
# 88325                                                -1
# 88330                                                -1
#
#       I had a negative experience or interaction at work  \
# 1                                                     -1
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# ...                                                  ...
# 88318                                                 -1
# 88320                                                 -1
# 88324                                                 -1
# 88325                                                 -1
# 88330                                                 -1
#
#       Re-entry into the workforce ExtraversionCol Online  IRL
# 1                              -1             1.0    1.0  NaN
# 2                              -1             1.0    NaN  1.0
# 3                              -1             1.0    NaN  1.0
# 4                              -1             1.0    NaN  1.0
# 5                              -1             1.0    NaN  1.0
# ...                           ...             ...    ...  ...
# 88318                          -1             1.0    NaN  1.0
# 88320                          -1             1.0    NaN  1.0
# 88324                          -1             1.0    1.0  NaN
# 88325                          -1             1.0    1.0  NaN
# 88330                          -1             1.0    NaN  1.0
#
# [42938 rows x 28 columns]

# %%
online_df = df
online_df = online_df.drop(columns = "IRL")
online_df = online_df.dropna()

irl_df = df
irl_df = irl_df.drop(columns = "Online")
irl_df = irl_df.dropna()

display(online_df)
display(irl_df)
# Out:
#        Hobbyist  OpenSourcer ResumeUpdate BetterLife ITperson SocialMedia  \
# 1            -1         -0.5        False        Yes      Yes   Instagram
# 13            1         -0.5        False        Yes      Yes      Reddit
# 15            1         -1.0        False         No     SIGH     YouTube
# 21            1         -0.5        False        Yes      Yes   Instagram
# 23            1         -1.0        False        Yes      Yes      Reddit
# ...         ...          ...          ...        ...      ...         ...
# 88307         1         -0.5        False         No      Yes    WhatsApp
# 88310         1         -0.5        False        Yes      Yes    WhatsApp
# 88317         1         -1.0        False         No      Yes    LinkedIn
# 88324         1         -0.5        False        Yes      Yes    Facebook
# 88325         1         -0.5        False        Yes      Yes     Twitter
#
#       Extraversion  SOVisitFreq  \
# 1           Online          1.0
# 13          Online          1.0
# 15          Online          1.0
# 21          Online          1.0
# 23          Online          1.0
# ...            ...          ...
# 88307      Neither          1.0
# 88310       Online          1.0
# 88317       Online          0.5
# 88324       Online          0.0
# 88325       Online          1.0
#
#                                                SOVisitTo  SOFindAnswer  ...  \
# 1      Find answers to specific questions;Learn how t...           0.5  ...
# 13                    Find answers to specific questions           0.5  ...
# 15     Find answers to specific questions;Learn how t...          -0.5  ...
# 21                    Find answers to specific questions           0.5  ...
# 23                    Find answers to specific questions           0.5  ...
# ...                                                  ...           ...  ...
# 88307  Find answers to specific questions;Learn how t...           1.0  ...
# 88310                 Find answers to specific questions           1.0  ...
# 88317                 Find answers to specific questions           0.0  ...
# 88324                 Find answers to specific questions          -0.5  ...
# 88325  Find answers to specific questions;Learn how t...           0.5  ...
#
#        Trans                Sexuality  \
# 1         No  Straight / Heterosexual
# 13        No  Straight / Heterosexual
# 15        No  Straight / Heterosexual
# 21        No  Straight / Heterosexual
# 23        No  Straight / Heterosexual
# ...      ...                      ...
# 88307     No  Straight / Heterosexual
# 88310     No                 Bisexual
# 88317     No  Straight / Heterosexual
# 88324     No  Straight / Heterosexual
# 88325     No  Straight / Heterosexual
#
#        Something else changed (education, award, media, etc.)  \
# 1                                                      1
# 13                                                     1
# 15                                                    -1
# 21                                                    -1
# 23                                                    -1
# ...                                                  ...
# 88307                                                 -1
# 88310                                                 -1
# 88317                                                 -1
# 88324                                                 -1
# 88325                                                 -1
#
#        I was preparing for a job search  \
# 1                                     1
# 13                                    1
# 15                                   -1
# 21                                   -1
# 23                                   -1
# ...                                 ...
# 88307                                -1
# 88310                                -1
# 88317                                -1
# 88324                                -1
# 88325                                -1
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                     -1
# 13                                                    -1
# 15                                                    -1
# 21                                                    -1
# 23                                                    -1
# ...                                                  ...
# 88307                                                 -1
# 88310                                                 -1
# 88317                                                 -1
# 88324                                                 -1
# 88325                                                 -1
#
#       My job status changed (promotion, new job, etc.)  \
# 1                                                   -1
# 13                                                  -1
# 15                                                  -1
# 21                                                  -1
# 23                                                  -1
# ...                                                ...
# 88307                                               -1
# 88310                                               -1
# 88317                                               -1
# 88324                                               -1
# 88325                                               -1
#
#       I had a negative experience or interaction at work  \
# 1                                                     -1
# 13                                                    -1
# 15                                                    -1
# 21                                                    -1
# 23                                                    -1
# ...                                                  ...
# 88307                                                 -1
# 88310                                                 -1
# 88317                                                 -1
# 88324                                                 -1
# 88325                                                 -1
#
#       Re-entry into the workforce ExtraversionCol  Online
# 1                              -1             1.0     1.0
# 13                             -1             1.0     1.0
# 15                             -1             1.0     1.0
# 21                             -1             1.0     1.0
# 23                             -1             1.0     1.0
# ...                           ...             ...     ...
# 88307                          -1             0.0    -1.0
# 88310                          -1             1.0     1.0
# 88317                          -1             1.0     1.0
# 88324                          -1             1.0     1.0
# 88325                          -1             1.0     1.0
#
# [16070 rows x 27 columns]
#        Hobbyist  OpenSourcer ResumeUpdate BetterLife  ITperson SocialMedia  \
# 2             1         -1.0        False        Yes       Yes      Reddit
# 3            -1         -1.0        False        Yes      SIGH      Reddit
# 4             1          1.0        False        Yes  Also Yes    Facebook
# 5             1         -1.0        False         No       Yes     YouTube
# 12            1          0.5        False        Yes       Yes     Twitter
# ...         ...          ...          ...        ...       ...         ...
# 88307         1         -0.5        False         No       Yes    WhatsApp
# 88313         1         -1.0        False         No       Yes     YouTube
# 88318         1         -0.5        False        Yes      SIGH      Reddit
# 88320         1          0.5        False         No  Also Yes     YouTube
# 88330         1          1.0        False        Yes      SIGH      Reddit
#
#                    Extraversion  SOVisitFreq  \
# 2      In real life (in person)          0.5
# 3      In real life (in person)          1.0
# 4      In real life (in person)          1.0
# 5      In real life (in person)          0.0
# 12     In real life (in person)          1.0
# ...                         ...          ...
# 88307                   Neither          1.0
# 88313  In real life (in person)          1.0
# 88318  In real life (in person)          1.0
# 88320  In real life (in person)          1.0
# 88330  In real life (in person)          0.5
#
#                                                SOVisitTo  SOFindAnswer  ...  \
# 2      Find answers to specific questions;Learn how t...           1.0  ...
# 3      Find answers to specific questions;Pass the ti...           0.0  ...
# 4                     Find answers to specific questions           1.0  ...
# 5                     Find answers to specific questions          -0.5  ...
# 12                    Find answers to specific questions           1.0  ...
# ...                                                  ...           ...  ...
# 88307  Find answers to specific questions;Learn how t...           1.0  ...
# 88313  Find answers to specific questions;Learn how t...           0.0  ...
# 88318  Find answers to specific questions;Learn how t...           1.0  ...
# 88320  Find answers to specific questions;Learn how t...           1.0  ...
# 88330  Find answers to specific questions;Learn how t...           0.0  ...
#
#        Trans                Sexuality  \
# 2         No  Straight / Heterosexual
# 3         No  Straight / Heterosexual
# 4         No  Straight / Heterosexual
# 5         No  Straight / Heterosexual
# 12        No  Straight / Heterosexual
# ...      ...                      ...
# 88307     No  Straight / Heterosexual
# 88313     No  Straight / Heterosexual
# 88318     No  Straight / Heterosexual
# 88320     No           Gay or Lesbian
# 88330     No  Straight / Heterosexual
#
#        Something else changed (education, award, media, etc.)  \
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# 12                                                    -1
# ...                                                  ...
# 88307                                                 -1
# 88313                                                 -1
# 88318                                                 -1
# 88320                                                 -1
# 88330                                                 -1
#
#        I was preparing for a job search  \
# 2                                    -1
# 3                                    -1
# 4                                    -1
# 5                                    -1
# 12                                   -1
# ...                                 ...
# 88307                                -1
# 88313                                -1
# 88318                                -1
# 88320                                -1
# 88330                                -1
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# 12                                                    -1
# ...                                                  ...
# 88307                                                 -1
# 88313                                                 -1
# 88318                                                 -1
# 88320                                                 -1
# 88330                                                 -1
#
#       My job status changed (promotion, new job, etc.)  \
# 2                                                   -1
# 3                                                   -1
# 4                                                   -1
# 5                                                   -1
# 12                                                  -1
# ...                                                ...
# 88307                                               -1
# 88313                                               -1
# 88318                                               -1
# 88320                                               -1
# 88330                                               -1
#
#       I had a negative experience or interaction at work  \
# 2                                                     -1
# 3                                                     -1
# 4                                                     -1
# 5                                                     -1
# 12                                                    -1
# ...                                                  ...
# 88307                                                 -1
# 88313                                                 -1
# 88318                                                 -1
# 88320                                                 -1
# 88330                                                 -1
#
#       Re-entry into the workforce ExtraversionCol  IRL
# 2                              -1             1.0  1.0
# 3                              -1             1.0  1.0
# 4                              -1             1.0  1.0
# 5                              -1             1.0  1.0
# 12                             -1             1.0  1.0
# ...                           ...             ...  ...
# 88307                          -1             0.0 -1.0
# 88313                          -1             1.0  1.0
# 88318                          -1             1.0  1.0
# 88320                          -1             1.0  1.0
# 88330                          -1             1.0  1.0
#
# [30681 rows x 27 columns]

# %%
import numpy as np

online_df_ten = int(0.1 * len(online_df))
online_df_eighty = int(0.8 * len(online_df))
online_df_ninety = int(0.9 * len(online_df))

split_arrays = np.split(online_df, [online_df_eighty, online_df_ninety])
# split_tens = np.split(split_arrays[1], df_ten)

# df_train = df.iloc[:, :df_eighty]
# df_validation = df.iloc[:, df_eighty:df_ninety]
# df_test = df.iloc[:, df_ninety:]

online_df_train = pd.DataFrame(split_arrays[0])
online_df_validate = pd.DataFrame(split_arrays[1])
online_df_test = pd.DataFrame(split_arrays[2])

print(len(online_df_train))
print(len(online_df_validate))
# Out:
# 12856
# 1607

# %%
irl_df_ten = int(0.1 * len(irl_df))
irl_df_eighty = int(0.8 * len(irl_df))
irl_df_ninety = int(0.9 * len(irl_df))

split_arrays_irl = np.split(irl_df, [irl_df_eighty, irl_df_ninety])
# split_tens = np.split(split_arrays[1], df_ten)

# df_train = df.iloc[:, :df_eighty]
# df_validation = df.iloc[:, df_eighty:df_ninety]
# df_test = df.iloc[:, df_ninety:]

irl_df_train = pd.DataFrame(split_arrays_irl[0])
irl_df_validate = pd.DataFrame(split_arrays_irl[1])
irl_df_test = pd.DataFrame(split_arrays_irl[2])

print(len(irl_df_train))
print(len(irl_df_validate))
# Out:
# 24544
# 3068

# %%
df_ten = int(0.1 * len(df))
df_eighty = int(0.8 * len(df))
df_ninety = int(0.9 * len(df))

split_arrays_irl = np.split(df, [df_eighty, df_ninety])
# split_tens = np.split(split_arrays[1], df_ten)

# df_train = df.iloc[:, :df_eighty]
# df_validation = df.iloc[:, df_eighty:df_ninety]
# df_test = df.iloc[:, df_ninety:]

df_train = pd.DataFrame(split_arrays_irl[0])
df_validate = pd.DataFrame(split_arrays_irl[1])
df_test = pd.DataFrame(split_arrays_irl[2])

print(len(df_train))
print(len(df_validate))
# Out:
# 34350
# 4294

# %%
num_positive = 0
num_negative = 0
filtered_df = pd.DataFrame()
i = 0
indexNamesArr = df_train.index.values
column_index = df_train.columns.get_indexer_for(['ExtraversionCol'])[0]
while num_positive < 2500 or num_negative < 2500:
    column_val = df_train.iloc[i, column_index]
    if column_val < 1 and num_negative < 2500:
        num_negative += 1
        filtered_df = filtered_df.append(df_train.loc[indexNamesArr[i], :])
    elif column_val == 1 and num_positive < 2500:
        num_positive += 1
        filtered_df = filtered_df.append(df_train.loc[indexNamesArr[i], :])
    i += 1
    
display(filtered_df)
print(i)
# Out:
#       BetterLife  EntTeams              Extraversion  ExtraversionCol Gender  \
# 1            Yes      -1.0                    Online              1.0    Man
# 2            Yes      -1.0  In real life (in person)              1.0    Man
# 3            Yes      -1.0  In real life (in person)              1.0    Man
# 4            Yes      -1.0  In real life (in person)              1.0    Man
# 5             No      -1.0  In real life (in person)              1.0    Man
# ...          ...       ...                       ...              ...    ...
# 57913         No      -1.0                   Neither              0.0  Woman
# 57967        Yes      -1.0                   Neither              0.0    Man
# 57983        Yes      -1.0                   Neither              0.0    Man
# 58040        Yes      -1.0                   Neither              0.0    Man
# 58045         No      -1.0                   Neither              0.0    Man
#
#        Hobbyist  I had a negative experience or interaction at work  \
# 1          -1.0                                               -1.0
# 2           1.0                                               -1.0
# 3          -1.0                                               -1.0
# 4           1.0                                               -1.0
# 5           1.0                                               -1.0
# ...         ...                                                ...
# 57913      -1.0                                               -1.0
# 57967       1.0                                               -1.0
# 57983       1.0                                               -1.0
# 58040       1.0                                               -1.0
# 58045       1.0                                               -1.0
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                   -1.0
# 2                                                   -1.0
# 3                                                   -1.0
# 4                                                   -1.0
# 5                                                   -1.0
# ...                                                  ...
# 57913                                               -1.0
# 57967                                               -1.0
# 57983                                               -1.0
# 58040                                               -1.0
# 58045                                               -1.0
#
#        I was preparing for a job search  IRL  ... SOFindAnswer  SOJobs  \
# 1                                   1.0  NaN  ...          0.5    -1.0
# 2                                  -1.0  1.0  ...          1.0     1.0
# 3                                  -1.0  1.0  ...          0.0     1.0
# 4                                  -1.0  1.0  ...          1.0    -1.0
# 5                                  -1.0  1.0  ...         -0.5    -1.0
# ...                                 ...  ...  ...          ...     ...
# 57913                              -1.0 -1.0  ...          1.0    -1.0
# 57967                              -1.0 -1.0  ...          1.0    -1.0
# 57983                               1.0 -1.0  ...          0.0    -1.0
# 58040                              -1.0 -1.0  ...          1.0    -1.0
# 58045                              -1.0 -1.0  ...          1.0     1.0
#
#                                             SONewContent  SOPartFreq  \
# 1      Tech articles written by other developers;Indu...         0.0
# 2      Tech meetups or events in your area;Courses on...        -0.5
# 3      Tech articles written by other developers;Indu...        -0.5
# 4      Tech meetups or events in your area;Courses on...         0.0
# 5      Tech articles written by other developers;Indu...        -1.0
# ...                                                  ...         ...
# 57913  Tech articles written by other developers;Indu...        -1.0
# 57967  Tech articles written by other developers;Tech...         0.0
# 57983  Tech articles written by other developers;Indu...         0.5
# 58040          Tech articles written by other developers        -0.5
# 58045       Courses on technologies you're interested in         0.5
#
#        SOVisitFreq                                          SOVisitTo  \
# 1              1.0  Find answers to specific questions;Learn how t...
# 2              0.5  Find answers to specific questions;Learn how t...
# 3              1.0  Find answers to specific questions;Pass the ti...
# 4              1.0                 Find answers to specific questions
# 5              0.0                 Find answers to specific questions
# ...            ...                                                ...
# 57913          1.0                 Find answers to specific questions
# 57967          0.5  Find answers to specific questions;Learn how t...
# 57983          0.5  Find answers to specific questions;Learn how t...
# 58040          1.0                 Find answers to specific questions
# 58045          1.0  Find answers to specific questions;Pass the ti...
#
#                      Sexuality  SocialMedia  \
# 1      Straight / Heterosexual    Instagram
# 2      Straight / Heterosexual       Reddit
# 3      Straight / Heterosexual       Reddit
# 4      Straight / Heterosexual     Facebook
# 5      Straight / Heterosexual      YouTube
# ...                        ...          ...
# 57913  Straight / Heterosexual     Facebook
# 57967  Straight / Heterosexual      YouTube
# 57983                 Bisexual     WhatsApp
# 58040  Straight / Heterosexual    Instagram
# 58045  Straight / Heterosexual     Facebook
#
#        Something else changed (education, award, media, etc.)  Trans
# 1                                                    1.0          No
# 2                                                   -1.0          No
# 3                                                   -1.0          No
# 4                                                   -1.0          No
# 5                                                   -1.0          No
# ...                                                  ...         ...
# 57913                                               -1.0          No
# 57967                                               -1.0          No
# 57983                                                1.0          No
# 58040                                               -1.0          No
# 58045                                               -1.0          No
#
# [5000 rows x 28 columns]
# 28245

# %%
print(column_index)
print(filtered_df.iloc[1499, column_index])
# Out:
# 25
# Twitter

# %%
display(filtered_df)
print(len(filtered_df))
# Out:
#       BetterLife  EntTeams              Extraversion  ExtraversionCol Gender  \
# 1            Yes      -1.0                    Online              1.0    Man
# 2            Yes      -1.0  In real life (in person)              1.0    Man
# 3            Yes      -1.0  In real life (in person)              1.0    Man
# 4            Yes      -1.0  In real life (in person)              1.0    Man
# 5             No      -1.0  In real life (in person)              1.0    Man
# ...          ...       ...                       ...              ...    ...
# 57913         No      -1.0                   Neither              0.0  Woman
# 57967        Yes      -1.0                   Neither              0.0    Man
# 57983        Yes      -1.0                   Neither              0.0    Man
# 58040        Yes      -1.0                   Neither              0.0    Man
# 58045         No      -1.0                   Neither              0.0    Man
#
#        Hobbyist  I had a negative experience or interaction at work  \
# 1          -1.0                                               -1.0
# 2           1.0                                               -1.0
# 3          -1.0                                               -1.0
# 4           1.0                                               -1.0
# 5           1.0                                               -1.0
# ...         ...                                                ...
# 57913      -1.0                                               -1.0
# 57967       1.0                                               -1.0
# 57983       1.0                                               -1.0
# 58040       1.0                                               -1.0
# 58045       1.0                                               -1.0
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 1                                                   -1.0
# 2                                                   -1.0
# 3                                                   -1.0
# 4                                                   -1.0
# 5                                                   -1.0
# ...                                                  ...
# 57913                                               -1.0
# 57967                                               -1.0
# 57983                                               -1.0
# 58040                                               -1.0
# 58045                                               -1.0
#
#        I was preparing for a job search  IRL  ... SOFindAnswer  SOJobs  \
# 1                                   1.0  NaN  ...          0.5    -1.0
# 2                                  -1.0  1.0  ...          1.0     1.0
# 3                                  -1.0  1.0  ...          0.0     1.0
# 4                                  -1.0  1.0  ...          1.0    -1.0
# 5                                  -1.0  1.0  ...         -0.5    -1.0
# ...                                 ...  ...  ...          ...     ...
# 57913                              -1.0 -1.0  ...          1.0    -1.0
# 57967                              -1.0 -1.0  ...          1.0    -1.0
# 57983                               1.0 -1.0  ...          0.0    -1.0
# 58040                              -1.0 -1.0  ...          1.0    -1.0
# 58045                              -1.0 -1.0  ...          1.0     1.0
#
#                                             SONewContent  SOPartFreq  \
# 1      Tech articles written by other developers;Indu...         0.0
# 2      Tech meetups or events in your area;Courses on...        -0.5
# 3      Tech articles written by other developers;Indu...        -0.5
# 4      Tech meetups or events in your area;Courses on...         0.0
# 5      Tech articles written by other developers;Indu...        -1.0
# ...                                                  ...         ...
# 57913  Tech articles written by other developers;Indu...        -1.0
# 57967  Tech articles written by other developers;Tech...         0.0
# 57983  Tech articles written by other developers;Indu...         0.5
# 58040          Tech articles written by other developers        -0.5
# 58045       Courses on technologies you're interested in         0.5
#
#        SOVisitFreq                                          SOVisitTo  \
# 1              1.0  Find answers to specific questions;Learn how t...
# 2              0.5  Find answers to specific questions;Learn how t...
# 3              1.0  Find answers to specific questions;Pass the ti...
# 4              1.0                 Find answers to specific questions
# 5              0.0                 Find answers to specific questions
# ...            ...                                                ...
# 57913          1.0                 Find answers to specific questions
# 57967          0.5  Find answers to specific questions;Learn how t...
# 57983          0.5  Find answers to specific questions;Learn how t...
# 58040          1.0                 Find answers to specific questions
# 58045          1.0  Find answers to specific questions;Pass the ti...
#
#                      Sexuality  SocialMedia  \
# 1      Straight / Heterosexual    Instagram
# 2      Straight / Heterosexual       Reddit
# 3      Straight / Heterosexual       Reddit
# 4      Straight / Heterosexual     Facebook
# 5      Straight / Heterosexual      YouTube
# ...                        ...          ...
# 57913  Straight / Heterosexual     Facebook
# 57967  Straight / Heterosexual      YouTube
# 57983                 Bisexual     WhatsApp
# 58040  Straight / Heterosexual    Instagram
# 58045  Straight / Heterosexual     Facebook
#
#        Something else changed (education, award, media, etc.)  Trans
# 1                                                    1.0          No
# 2                                                   -1.0          No
# 3                                                   -1.0          No
# 4                                                   -1.0          No
# 5                                                   -1.0          No
# ...                                                  ...         ...
# 57913                                               -1.0          No
# 57967                                               -1.0          No
# 57983                                                1.0          No
# 58040                                               -1.0          No
# 58045                                               -1.0          No
#
# [5000 rows x 28 columns]
# 5000

# %%
num_positive = 0
num_negative = 0
filtered_df_validate = pd.DataFrame()
i = 0
indexNamesArr = df_validate.index.values
column_index = df_validate.columns.get_indexer_for(['ExtraversionCol'])[0]
while num_positive < 250 or num_negative < 250:
    column_val = df_validate.iloc[i, column_index]
    if column_val < 1 and num_negative < 250:
        num_negative += 1
        filtered_df_validate = filtered_df_validate.append(df_validate.loc[indexNamesArr[i], :])
    elif column_val == 1 and num_positive < 250:
        num_positive += 1
        filtered_df_validate = filtered_df_validate.append(df_validate.loc[indexNamesArr[i], :])
    i += 1
    
display(filtered_df_validate)
print(i)
# Out:
#       BetterLife  EntTeams              Extraversion  ExtraversionCol Gender  \
# 70476        Yes      -1.0  In real life (in person)              1.0    Man
# 70478        Yes      -1.0                    Online              1.0    Man
# 70480         No      -1.0  In real life (in person)              1.0    Man
# 70481        Yes      -1.0                    Online              1.0    Man
# 70482        Yes      -1.0  In real life (in person)              1.0    Man
# ...          ...       ...                       ...              ...    ...
# 75586        Yes      -1.0                   Neither              0.0    Man
# 75604        Yes      -1.0                   Neither              0.0    Man
# 75632        Yes       1.0                   Neither              0.0    Man
# 75641         No      -1.0                   Neither              0.0    Man
# 75688         No      -1.0                   Neither              0.0    Man
#
#        Hobbyist  I had a negative experience or interaction at work  \
# 70476       1.0                                               -1.0
# 70478       1.0                                               -1.0
# 70480       1.0                                               -1.0
# 70481       1.0                                               -1.0
# 70482       1.0                                               -1.0
# ...         ...                                                ...
# 75586       1.0                                               -1.0
# 75604       1.0                                               -1.0
# 75632       1.0                                               -1.0
# 75641       1.0                                               -1.0
# 75688      -1.0                                               -1.0
#
#        I heard about a job opportunity (from a recruiter, online job posting, etc.)  \
# 70476                                               -1.0
# 70478                                               -1.0
# 70480                                               -1.0
# 70481                                               -1.0
# 70482                                               -1.0
# ...                                                  ...
# 75586                                               -1.0
# 75604                                               -1.0
# 75632                                               -1.0
# 75641                                               -1.0
# 75688                                               -1.0
#
#        I was preparing for a job search  IRL  ... SOFindAnswer  SOJobs  \
# 70476                              -1.0  1.0  ...          1.0     1.0
# 70478                              -1.0  NaN  ...          1.0     1.0
# 70480                              -1.0  1.0  ...          1.0     1.0
# 70481                              -1.0  NaN  ...          1.0     1.0
# 70482                              -1.0  1.0  ...          1.0     1.0
# ...                                 ...  ...  ...          ...     ...
# 75586                              -1.0 -1.0  ...         -0.5     1.0
# 75604                              -1.0 -1.0  ...          0.0     1.0
# 75632                              -1.0 -1.0  ...          0.0    -1.0
# 75641                              -1.0 -1.0  ...          0.0    -1.0
# 75688                              -1.0 -1.0  ...          0.0    -1.0
#
#                                             SONewContent  SOPartFreq  \
# 70476  Tech articles written by other developers;Indu...        -1.0
# 70478  Tech articles written by other developers;Indu...        -0.5
# 70480  Tech articles written by other developers;Indu...        -0.5
# 70481  Industry news about technologies you're intere...         0.0
# 70482       Courses on technologies you're interested in        -0.5
# ...                                                  ...         ...
# 75586  Tech articles written by other developers;Cour...        -0.5
# 75604  Tech articles written by other developers;Indu...        -0.5
# 75632       Courses on technologies you're interested in         0.0
# 75641  Tech articles written by other developers;Indu...        -0.5
# 75688  Tech articles written by other developers;Tech...        -0.5
#
#        SOVisitFreq                                          SOVisitTo  \
# 70476          1.0  Find answers to specific questions;Learn how t...
# 70478          1.0  Find answers to specific questions;Learn how t...
# 70480          1.0  Find answers to specific questions;Learn how t...
# 70481          1.0  Find answers to specific questions;Pass the ti...
# 70482          1.0                 Find answers to specific questions
# ...            ...                                                ...
# 75586         -0.5  Find answers to specific questions;Learn how t...
# 75604          1.0  Find answers to specific questions;Learn how t...
# 75632          0.5  Find answers to specific questions;Learn how t...
# 75641          0.5  Find answers to specific questions;Learn how t...
# 75688          0.0  Find answers to specific questions;Learn how t...
#
#                      Sexuality               SocialMedia  \
# 70476  Straight / Heterosexual  I don't use social media
# 70478  Straight / Heterosexual                  Facebook
# 70480  Straight / Heterosexual                   Twitter
# 70481  Straight / Heterosexual                    Reddit
# 70482  Straight / Heterosexual                  LinkedIn
# ...                        ...                       ...
# 75586  Straight / Heterosexual  I don't use social media
# 75604  Straight / Heterosexual  I don't use social media
# 75632  Straight / Heterosexual                  WhatsApp
# 75641  Straight / Heterosexual  I don't use social media
# 75688  Straight / Heterosexual                   YouTube
#
#        Something else changed (education, award, media, etc.)  Trans
# 70476                                               -1.0          No
# 70478                                               -1.0          No
# 70480                                               -1.0          No
# 70481                                               -1.0          No
# 70482                                               -1.0          No
# ...                                                  ...         ...
# 75586                                               -1.0          No
# 75604                                               -1.0          No
# 75632                                               -1.0          No
# 75641                                               -1.0          No
# 75688                                               -1.0          No
#
# [500 rows x 28 columns]
# 2518

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# df = text_to_scores(df, 'SOAccount', soAccount_bins, soAccount_scores)
# df = text_to_scores(df, 'SOPartFreq', soFreq_bins, soFreq_scores)
# df = text_to_scores(df, 'SOVisitFreq', soFreq_bins, soFreq_scores)
# df = text_to_scores(df, 'I was preparing for a job search', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'Something else changed (education, award, media, etc.)', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'I heard about a job opportunity (from a recruiter, online job posting, etc.)', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'My job status changed (promotion, new job, etc.)', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'I had a negative experience or interaction at work', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'Re-entry into the workforce', boolean_bins, boolean_scores)
# df = text_to_scores(df, 'OpenSourcer', opensourcer_bins, opensourcer_scores)
# df = text_to_scores(df, 'SOFindAnswer', findAnswer_bins, findAnswer_scores)
# df = text_to_scores(df, 'SOJobs', soJobs_bins, soJobs_scores)
# df = text_to_scores(df, 'EntTeams', soTeams_bins, soTeams_scores)
# df = text_to_scores(df, 'Hobbyist', binary_bins, binary_scores)

X_features = ["SOAccount", 'SOPartFreq', "SOVisitFreq", "OpenSourcer", "SOFindAnswer", "SOJobs", "EntTeams", "Hobbyist"]
# X_features.append("I was preparing for a job search")
# X_features.append("Something else changed (education, award, media, etc.)")
# X_features.append("I heard about a job opportunity (from a recruiter, online job posting, etc.)")
# X_features.append("I had a negative experience or interaction at work")
# X_features.append("Re-entry into the workforce")

itera = 1000
weight = "balanced"
intercept = True
class_multi = 'auto'
set_c = float(0.01)
start = True

model = LogisticRegression(max_iter=itera, class_weight=weight, warm_start=start, fit_intercept=intercept, C=set_c, multi_class=class_multi)
model.fit(df_train.loc[:, X_features], df_train.loc[:, 'ExtraversionCol'])

# new_model = LogisticRegression(max_iter=1000)
# new_model.fit(old_df_train.loc[:, X_features], old_df_train.loc[:, 'Online'])
# Out:
# LogisticRegression(C=0.01, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=1000, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=True)

# %%
true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
column_index = filtered_df.columns.get_indexer_for(["ExtraversionCol"])[0]
prediction = model.predict(filtered_df.loc[:, X_features])
# print(prediction)
# print(filtered_df.IRL.unique())

for p in range(len(prediction)):
    row_prediction = prediction[p]
    true_value = (filtered_df.iloc[p, column_index])
#     print(str(true_value) + "true vs. " + str(row_prediction))
    if true_value == 1:
        if row_prediction == 1:
            true_positives +=1
        else:
            false_negatives += 1
    else:
        if row_prediction == -1:
            true_negatives += 1
        else:
            false_positives += 1
            
print("True positives: " + str(true_positives))
print("True negatives: " + str(true_negatives))
print("False positives: " + str(false_positives))
print("False negatives: " + str(false_negatives))
print("Total correct: " + str(true_positives+true_negatives))
print("F1-score: " + str(f1_score(filtered_df.loc[:, "ExtraversionCol"], prediction, average='weighted')))
# Out:
# True positives: 1346
# True negatives: 0
# False positives: 2500
# False negatives: 1154
# Total correct: 1346
# F1-score: 0.5196338125137773

# %%
true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
column_index = filtered_df_validate.columns.get_indexer_for(["ExtraversionCol"])[0]
prediction = model.predict(filtered_df_validate.loc[:, X_features])
# print(prediction)
# print(filtered_df.IRL.unique())

for p in range(len(prediction)):
    row_prediction = int(prediction[p])
    true_value = int(filtered_df_validate.iloc[p, column_index])
#     print(str(true_value) + "true vs. " + str(row_prediction))
    if true_value == 1:
        if row_prediction == true_value:
            true_positives +=1
        else:
            false_negatives += 1
    elif true_value == -1:
        if row_prediction == true_value:
            true_negatives += 1
        else:
            false_positives += 1
            
print("True positives: " + str(true_positives))
print("True negatives: " + str(true_negatives))
print("False positives: " + str(false_positives))
print("False negatives: " + str(false_negatives))
print("F1-score: " + str(f1_score(filtered_df_validate.loc[:, "ExtraversionCol"], prediction, average='weighted')))
# Out:
# True positives: 118
# True negatives: 0
# False positives: 0
# False negatives: 132
# F1-score: 0.49766041844286746

# %%
true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
column_index = df_train.columns.get_indexer_for(["ExtraversionCol"])[0]
prediction = model.predict(df_train.loc[:, X_features])
# print(prediction)
# print(filtered_df.IRL.unique())

for p in range(len(prediction)):
    row_prediction = int(prediction[p])
    true_value = int(df_train.iloc[p, column_index])
#     print(str(true_value) + "true vs. " + str(row_prediction))
    if true_value == 1:
        if row_prediction == true_value:
            true_positives +=1
        else:
            false_negatives += 1
    else:
        if row_prediction == true_value:
            true_negatives += 1
        else:
            false_positives += 1
            
print("True positives: " + str(true_positives))
print("True negatives: " + str(true_negatives))
print("False positives: " + str(false_positives))
print("False negatives: " + str(false_negatives))
print("F1-score: " + str(f1_score(df_train.loc[:, "ExtraversionCol"], prediction, average='weighted')))
# Out:
# True positives: 16754
# True negatives: 1538
# False positives: 1470
# False negatives: 14588
# F1-score: 0.6309064360314358

# %%
true_positives = 0
false_positives = 0
true_negatives = 0
false_negatives = 0
column_index = df_validate.columns.get_indexer_for(["ExtraversionCol"])[0]
prediction = model.predict(df_validate.loc[:, X_features])
# print(prediction)
# print(filtered_df.IRL.unique())

for p in range(len(prediction)):
    row_prediction = int(prediction[p])
    true_value = int(df_validate.iloc[p, column_index])
#     print(str(true_value) + "true vs. " + str(row_prediction))
    if true_value == 1:
        if row_prediction == true_value:
            true_positives +=1
        else:
            false_negatives += 1
    else:
        if row_prediction == true_value:
            true_negatives += 1
        else:
            false_positives += 1
            
print("True positives: " + str(true_positives))
print("True negatives: " + str(true_negatives))
print("False positives: " + str(false_positives))
print("False negatives: " + str(false_negatives))
print("F1-score: " + str(f1_score(df_validate.loc[:, "ExtraversionCol"], prediction, average='weighted')))
# Out:
# True positives: 2049
# True negatives: 208
# False positives: 209
# False negatives: 1828
# F1-score: 0.6195716240116814

# %%
prediction = [True] * len(filtered_df)
print(str(f1_score(filtered_df.loc[:, "ExtraversionCol"], prediction, average='weighted')))
# Out:
# 0.3333333333333333

# %%
from matplotlib import pyplot as plt
print(X_features)
x_coords = []
for i in range(len(X_features)):
    x_coords.append(i)

python
print(len(weights))
print(weights)
bar_graph = plt.bar(x=x_coords, height=weights)
# Out:
# ['SOAccount', 'SOPartFreq', 'SOVisitFreq', 'OpenSourcer', 'SOFindAnswer', 'SOJobs', 'EntTeams', 'Hobbyist']
# 8
# [ 3.08164671e-05  4.82378279e-03 -1.05371982e-02  9.39605128e-02
#   1.08872652e-01 -2.58963083e-02  3.93714872e-02  7.54408059e-03]

# %%
weights.sort()
sorted_tags = ['SOJobs', "SOVisitFreq", "SOAccount", "SOPartFreq", "Hobbyist", "EntTeams", "OpenSourcer", "SOFindAnswer"]
print(weights)
bar_graph = plt.barh(y=x_coords, width=weights, tick_label=sorted_tags)
# Out:
# [-2.58963083e-02 -1.05371982e-02  3.08164671e-05  4.82378279e-03
#   7.54408059e-03  3.93714872e-02  9.39605128e-02  1.08872652e-01]

# %%
new_features = X_features[0:-1]
# new_features.append("Extraversion")
cleaned_df_new = new_df.dropna()
cleaned_df_new.loc[:, new_features].head()
# Out:
#     SOAccount                                         SOPartFreq  \
# 19        Yes  I have never participated in Q&A on Stack Over...
# 38        Yes                Less than once per month or monthly
# 43        Yes                Less than once per month or monthly
# 82        Yes                Less than once per month or monthly
# 103       Yes                             Multiple times per day
#
#                          SOVisitFreq  \
# 19   A few times per month or weekly
# 38            Multiple times per day
# 43              A few times per week
# 82             Daily or almost daily
# 103           Multiple times per day
#
#                                            OpenSourcer  \
# 19                                               Never
# 38                             Less than once per year
# 43                          Once a month or more often
# 82   Less than once a month but more than once per ...
# 103                                              Never
#
#                 SOFindAnswer  \
# 19        3-5 times per week
# 38        1-2 times per week
# 43        3-5 times per week
# 82       6-10 times per week
# 103  Less than once per week
#
#                                                 SOJobs  \
# 19   No, I didn't know that Stack Overflow had a jo...
# 38   No, I knew that Stack Overflow had a job board...
# 43                                                 Yes
# 82   No, I knew that Stack Overflow had a job board...
# 103                                                Yes
#
#                                               EntTeams Hobbyist  \
# 19                 No, and I don't know what those are       No
# 38   No, I've heard of them, but I am not part of a...      Yes
# 43   No, I've heard of them, but I am not part of a...      Yes
# 82                 No, and I don't know what those are      Yes
# 103                                                Yes      Yes
#
#                  Extraversion
# 19   In real life (in person)
# 38                     Online
# 43   In real life (in person)
# 82                     Online
# 103                    Online
